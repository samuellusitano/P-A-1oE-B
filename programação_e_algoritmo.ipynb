# %% [markdown]
# <a href="https://colab.research.google.com/github/samuellusitano/P-A-1oE-B/blob/main/programa%C3%A7%C3%A3o_e_algoritmo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de progamação e algoritmo
#
# *   Cálculo da área
#
# # Entrada
#
# *   ler lado1
# *   ler lado2
# # Processamento
# area = lado1 * lado2
# #Saída
# imprimir área

# %%
# Cálculo da área

# Emtrada

lado1 = 8
lado2 = 8


nome = "@samm.lustn"
idade = 15 #int
altura = 1.72 #float
numero_complexo = 4 + 1j #complex
esta_chovendo = False #bool

# %%
# Saída

print (f"Total da Área: {area}")
print (f"Insta dele: {nome}")
# Out:
# Total da Área: 64
# Insta dele: @samm.lustn
